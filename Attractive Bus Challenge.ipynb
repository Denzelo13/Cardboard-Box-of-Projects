# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Bus Patronage Data 2019.xlsx - 2019 Patronage Data.csv')

# %%
df.shape
# Out:
# (2481, 8)

# %%
df.sort_values(by='Weekday Average', ascending=False)[0:20]
# Out:
#       Bus Route  \
# 1468         98
# 160           5
# 1             3
# 290           7
# 0             3
# 159           5
# 291           7
# 513          28
# 1467         98
# 1380         89
# 260           5
# 1472         98
# 1694         99
# 129           3
# 1107         80
# 1374         89
# 850          60
# 851          60
# 678          29
# 514          28
#
#       INIT Bus stop number               (Please use this when requesting data)  \
# 1468                                                  4
# 160                                                   3
# 1                                                     3
# 290                                                   2
# 0                                                     1
# 159                                                   1
# 291                                                   4
# 513                                                   2
# 1467                                                  2
# ...

# %%
df.sort_values(by='Weekday Average', ascending=True)[0:10]
# Out:
#       Bus Route  \
# 1039         65
# 1273         87
# 1259         85
# 1197         80
# 1182         80
# 2226        135
# 1075         73
# 844          45
# 1279         87
# 816          45
#
#       INIT Bus stop number               (Please use this when requesting data)  \
# 1039                                               1050
# 1273                                               1482
# 1259                                               3325
# 1197                                               1558
# 1182                                               1058
# 2226                                                487
# 1075                                                599
# 844                                                4059
# 1279                                               1683
# 816                                                1931
#
#       Adult  Child  Total  Weekday Average  Street Bus stop number  \
# ...

# %%
df[df['Weekday Average'] < 1]
# Out:
#       Bus Route  \
# 5             3
# 15            3
# 17            3
# 19            3
# 20            3
# ...         ...
# 2469        155
# 2470        155
# 2471        155
# 2472        155
# 2474        667
#
#       INIT Bus stop number               (Please use this when requesting data)  \
# 5                                                   340
# 15                                                  476
# 17                                                  478
# 19                                                  481
# 20                                                  482
# ...                                                 ...
# 2469                                               3266
# 2470                                               3313
# 2471                                               3314
# 2472                                               3315
# 2474                                                520
#
# ...

# %%
df['Total'].plot.hist(bins=30)

# %%
df['Total'].describe()
# Out:
# count     2481.000000
# mean       404.002015
# std        965.951871
# min          1.000000
# 25%         36.000000
# 50%        138.000000
# 75%        393.000000
# max      14137.000000
# Name: Total, dtype: float64

# %%
df['Weekday Average'].describe()
# Out:
# count    2481.000000
# mean       19.238191
# std        45.997708
# min         0.047619
# 25%         1.714286
# 50%         6.571429
# 75%        18.714286
# max       673.190476
# Name: Weekday Average, dtype: float64

# %%
df['Weekday Average'].quantile(0.99)
# Out:
# 213.99047617999784

# %%
df['Weekday Average'].quantile(0.9)
# Out:
# 41.66666667

# %%
df['Weekday Average'].quantile(0.5)
# Out:
# 6.571428571
